# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import torchaudio
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# # Spektogram Creator
# Here we create two spektrogram datasets, with different encodings

# %%
#Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised)
emotionMap = {1: 'neutral', 2: 'calm', 3: 'happy',4: 'sad', 5: 'angry', 6: 'fearful', 7: 'disgust', 8: 'surprised'}

# %%
def load_audio_files(path: str):

    dataset = []
    walker = sorted(str(p) for p in Path(path).glob(f'*.wav'))

    for i, file_path in enumerate(walker):
        path, filename = os.path.split(file_path)
        
        label = str(emotionMap[int(filename[7:8])])
        # Load audio
        waveform, sample_rate = torchaudio.load(file_path)
        dataset.append([waveform, sample_rate, label])
        
    return dataset

# %%
def create_spectrogram_images(dataloader, phase):
    #make directory
    directory = f'./data/spectrograms/{phase}/'
    if not os.path.isdir(directory):
        os.makedirs(directory, exist_ok=True)
        
    for i, data in enumerate(dataloader):
        waveform = data[0]
        sample_rate = data[1][0]
        label = data[2][0]
        # create transformed waveforms
        spectrogram_tensor = torchaudio.transforms.MelSpectrogram(n_mels= 128, sample_rate=sample_rate,n_fft=2048)(waveform)     
        for map_ in ['jet','viridis']:
            fig = plt.figure(figsize=(10,10))
            plt.gca().set_axis_off()
            plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
            directory = f'./data/{map_}/spectrograms/{phase}/{label}/'
            if not os.path.isdir(directory):
                os.makedirs(directory, mode=0o777, exist_ok=True)
            plt.figure()
            plt.subplot(111)
            plt.axis('off')
            plt.box(False)
            fig1 = plt.gcf()
            plt.imshow(spectrogram_tensor[0].log2()[0,:,:].numpy(), cmap=map_)
            plt.draw()
            plt.box(False)
            fig1.savefig(f'./data/{map_}/spectrograms/{phase}/{label}/spec_img{i}.jpg', pad_inches = 0, bbox_inches='tight')
            plt.close('all')

# %%
# for phase in ['test','train']:
#     print(f'Now preparing {phase} data')
#     speechcommands = load_audio_files(f'../input/speechdataraw/{phase}/{phase}')
#     dataloader = torch.utils.data.DataLoader(speechcommands, batch_size=1,
#                                                 shuffle=False, num_workers=0)
#     create_spectrogram_images(dataloader, phase)

# %% [markdown]
# # Librosa Audio Processing

# %%
import numpy as np
import librosa
from PIL import Image
def get_melspectrogram_db(file_path, sr=None, n_fft=2048, hop_length=512, n_mels=128, fmin=20, fmax=8300, top_db=80):
    wav,sr = librosa.load(file_path,sr=sr)
    if wav.shape[0]<5*sr:
        wav=np.pad(wav,int(np.ceil((5*sr-wav.shape[0])/2)),mode='reflect')
    else:
        wav=wav[:5*sr]
    spec=librosa.feature.melspectrogram(wav, sr=sr, n_fft=n_fft,
              hop_length=hop_length,n_mels=n_mels,fmin=fmin,fmax=fmax)
    spec_db=librosa.power_to_db(spec,top_db=top_db)
    return spec_db



def spec_to_image(spec, eps=1e-6):
    mean = spec.mean()
    std = spec.std()
    spec_norm = (spec - mean) / (std + eps)
    spec_min, spec_max = spec_norm.min(), spec_norm.max()
    spec_scaled = 255 * (spec_norm - spec_min) / (spec_max - spec_min)
    spec_scaled = spec_scaled.astype(np.uint8)
    return spec_scaled


def load_audio_files_librosa(path: str, phase: str):

    dataset = []
    walker = sorted(str(p) for p in Path(path).glob(f'*.wav'))
    
    directory = f'./data/librosa/{phase}/'
    if not os.path.isdir(directory):
        os.makedirs(directory, exist_ok=True) 
    
    for i, file_path in enumerate(walker):
        path, filename = os.path.split(file_path)  
        label = str(emotionMap[int(filename[7:8])])
        spec = get_melspectrogram_db(file_path)
        spec_scaled = spec_to_image(spec)
        directory = f'./data/librosa/{phase}/{label}'
        if not os.path.isdir(directory):
            os.makedirs(directory, exist_ok=True) 
        im = Image.fromarray(spec_scaled)
        width, height = im.size   # Get dimensions

        left = (width - height)/2
        top = (height - height)/2
        right = (width + height)/2
        bottom = (height + height)/2

        # Crop the center of the image
        im = im.crop((left, top, right, bottom))
        im.save(f'./data/librosa/{phase}/{label}/{i}.jpeg')

# for phase in ['test','train']:
#     print(f'Now preparing {phase} data')
#     load_audio_files_librosa(f'../input/speechdataraw/{phase}/{phase}', phase)

# %% [markdown]
# # Train AlexNet with VIRIDIS encoding

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3,1,1))
    ]),
    'test': transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3,1,1)),
    ]),
}

data_dir = '../input/pytorchdata/data/librosa'
image_datasets = {x: torchvision.datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=8,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    train_acc = []
    test_acc = []
    train_loss = []
    test_loss = []
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            if phase == 'train':
                train_acc.append(epoch_acc.cpu())
                train_loss.append(epoch_loss)
            else:
                test_acc.append(epoch_acc.cpu())
                test_loss.append(epoch_loss)
            
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, train_acc, train_loss, test_acc, test_loss

# %%
epochs = 160

# %%
model_ft = models.alexnet(pretrained=True)
model_ft.classifier[6]=nn.Linear(4096, len(class_names), bias=True)
print(model_ft)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.00001,weight_decay=0.001)

# Decay LR by a factor of 0.1 every 30 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=100, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=8, bias=True)
#   )
# )

# %%
model, train_acc, train_loss, test_acc, test_loss = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=epochs)
torch.save(model.state_dict(), 'emotionRecognition_alex.pt')
# Out:
# Epoch 0/159
# ----------
# train Loss: 1.9951 Acc: 0.2350
# test Loss: 1.8507 Acc: 0.3125
#
# Epoch 1/159
# ----------
# train Loss: 1.6504 Acc: 0.4100
# test Loss: 1.6635 Acc: 0.4000
#
# Epoch 2/159
# ----------
# train Loss: 1.3981 Acc: 0.4767
# test Loss: 1.7434 Acc: 0.3708
#
# Epoch 3/159
# ----------
# train Loss: 1.2701 Acc: 0.5342
# test Loss: 1.7117 Acc: 0.4083
#
# Epoch 4/159
# ----------
# train Loss: 1.1494 Acc: 0.5708
# test Loss: 1.6619 Acc: 0.4125
#
# Epoch 5/159
# ----------
# train Loss: 1.0593 Acc: 0.5958
# test Loss: 1.7438 Acc: 0.4000
#
# Epoch 6/159
# ----------
# train Loss: 0.9686 Acc: 0.6492
# test Loss: 1.6808 Acc: 0.4083
#
# Epoch 7/159
# ----------
# train Loss: 0.8921 Acc: 0.6600
# test Loss: 1.7477 Acc: 0.4333
#
# Epoch 8/159
# ----------
# train Loss: 0.8207 Acc: 0.7083
# test Loss: 1.8181 Acc: 0.4417
#
# Epoch 9/159
# ----------
# train Loss: 0.7409 Acc: 0.7342
# test Loss: 1.7676 Acc: 0.4625
#
# Epoch 10/159
# ----------
# train Loss: 0.6698 Acc: 0.7675
# test Loss: 1.8111 Acc: 0.4458
#
# Epoch 11/159
# ----------
# train Loss: 0.6282 Acc: 0.7808
# test Loss: 1.9858 Acc: 0.4458
#
# Epoch 12/159
# ----------
# train Loss: 0.5622 Acc: 0.8058
# test Loss: 1.9826 Acc: 0.4417
#
# Epoch 13/159
# ----------
# train Loss: 0.5072 Acc: 0.8242
# test Loss: 2.0423 Acc: 0.4333
#
# Epoch 14/159
# ----------
# train Loss: 0.4648 Acc: 0.8325
# test Loss: 2.0283 Acc: 0.4417
#
# Epoch 15/159
# ----------
# train Loss: 0.4070 Acc: 0.8775
# test Loss: 2.1202 Acc: 0.4625
#
# Epoch 16/159
# ----------
# train Loss: 0.3384 Acc: 0.8933
# test Loss: 2.2857 Acc: 0.4792
#
# Epoch 17/159
# ----------
# train Loss: 0.3311 Acc: 0.8908
# test Loss: 2.4611 Acc: 0.4583
#
# Epoch 18/159
# ----------
# train Loss: 0.2995 Acc: 0.9033
# test Loss: 2.1927 Acc: 0.4750
#
# Epoch 19/159
# ----------
# train Loss: 0.2679 Acc: 0.9158
# test Loss: 2.2221 Acc: 0.4750
#
# Epoch 20/159
# ----------
# train Loss: 0.2322 Acc: 0.9375
# test Loss: 2.3967 Acc: 0.4583
#
# Epoch 21/159
# ----------
# train Loss: 0.2051 Acc: 0.9475
# test Loss: 2.3858 Acc: 0.5125
#
# Epoch 22/159
# ----------
# train Loss: 0.2007 Acc: 0.9392
# test Loss: 2.6819 Acc: 0.4833
#
# Epoch 23/159
# ----------
# train Loss: 0.1854 Acc: 0.9483
# test Loss: 2.5967 Acc: 0.4625
#
# Epoch 24/159
# ----------
# train Loss: 0.1552 Acc: 0.9592
# test Loss: 2.5940 Acc: 0.4625
#
# Epoch 25/159
# ----------
# train Loss: 0.1293 Acc: 0.9625
# test Loss: 2.5480 Acc: 0.4708
#
# Epoch 26/159
# ----------
# train Loss: 0.1081 Acc: 0.9758
# test Loss: 2.9651 Acc: 0.4792
#
# Epoch 27/159
# ----------
# train Loss: 0.1204 Acc: 0.9642
# test Loss: 2.8694 Acc: 0.4833
#
# Epoch 28/159
# ----------
# train Loss: 0.1069 Acc: 0.9692
# test Loss: 2.7275 Acc: 0.4750
#
# Epoch 29/159
# ----------
# train Loss: 0.0943 Acc: 0.9808
# test Loss: 2.9250 Acc: 0.4792
#
# Epoch 30/159
# ----------
# train Loss: 0.0708 Acc: 0.9842
# test Loss: 2.7326 Acc: 0.5042
#
# Epoch 31/159
# ----------
# train Loss: 0.0620 Acc: 0.9892
# test Loss: 3.0283 Acc: 0.4833
#
# Epoch 32/159
# ----------
# train Loss: 0.0714 Acc: 0.9825
# test Loss: 3.2512 Acc: 0.4542
#
# Epoch 33/159
# ----------
# train Loss: 0.0622 Acc: 0.9833
# test Loss: 3.0903 Acc: 0.4750
#
# Epoch 34/159
# ----------
# train Loss: 0.0533 Acc: 0.9900
# test Loss: 3.1741 Acc: 0.4583
#
# Epoch 35/159
# ----------
# train Loss: 0.0346 Acc: 0.9967
# test Loss: 3.5471 Acc: 0.4708
#
# Epoch 36/159
# ----------
# train Loss: 0.0693 Acc: 0.9792
# test Loss: 3.0931 Acc: 0.5125
#
# Epoch 37/159
# ----------
# train Loss: 0.0384 Acc: 0.9933
# test Loss: 3.4651 Acc: 0.4542
#
# Epoch 38/159
# ----------
# train Loss: 0.0603 Acc: 0.9817
# test Loss: 3.1293 Acc: 0.4500
#
# Epoch 39/159
# ----------
# train Loss: 0.0356 Acc: 0.9933
# test Loss: 3.1717 Acc: 0.4750
#
# Epoch 40/159
# ----------
# train Loss: 0.0418 Acc: 0.9900
# test Loss: 3.4587 Acc: 0.4333
#
# Epoch 41/159
# ----------
# train Loss: 0.0428 Acc: 0.9925
# test Loss: 3.4026 Acc: 0.5042
#
# Epoch 42/159
# ----------
# train Loss: 0.0320 Acc: 0.9917
# test Loss: 3.5211 Acc: 0.4750
#
# Epoch 43/159
# ----------
# train Loss: 0.0278 Acc: 0.9933
# test Loss: 3.4689 Acc: 0.4833
#
# Epoch 44/159
# ----------
# train Loss: 0.0165 Acc: 1.0000
# test Loss: 3.4672 Acc: 0.4708
#
# Epoch 45/159
# ----------
# train Loss: 0.0262 Acc: 0.9942
# test Loss: 3.7183 Acc: 0.4583
#
# Epoch 46/159
# ----------
# train Loss: 0.0250 Acc: 0.9975
# test Loss: 3.3858 Acc: 0.4917
#
# Epoch 47/159
# ----------
# train Loss: 0.0488 Acc: 0.9858
# test Loss: 3.4658 Acc: 0.4750
#
# Epoch 48/159
# ----------
# train Loss: 0.0299 Acc: 0.9950
# test Loss: 3.6714 Acc: 0.4833
#
# Epoch 49/159
# ----------
# train Loss: 0.0161 Acc: 0.9992
# test Loss: 3.7601 Acc: 0.4583
#
# Epoch 50/159
# ----------
# train Loss: 0.0303 Acc: 0.9917
# test Loss: 4.0478 Acc: 0.4458
#
# Epoch 51/159
# ----------
# train Loss: 0.0164 Acc: 0.9983
# test Loss: 3.8742 Acc: 0.4750
#
# Epoch 52/159
# ----------
# train Loss: 0.0210 Acc: 0.9958
# test Loss: 3.4899 Acc: 0.5000
#
# Epoch 53/159
# ----------
# train Loss: 0.0227 Acc: 0.9958
# test Loss: 3.6907 Acc: 0.4792
#
# Epoch 54/159
# ----------
# train Loss: 0.0218 Acc: 0.9942
# test Loss: 4.1085 Acc: 0.4667
#
# Epoch 55/159
# ----------
# train Loss: 0.0226 Acc: 0.9958
# test Loss: 4.0810 Acc: 0.4708
#
# Epoch 56/159
# ----------
# train Loss: 0.0117 Acc: 0.9992
# test Loss: 3.9262 Acc: 0.4542
#
# Epoch 57/159
# ----------
# train Loss: 0.0204 Acc: 0.9942
# test Loss: 3.9980 Acc: 0.4583
#
# Epoch 58/159
# ----------
# train Loss: 0.0348 Acc: 0.9925
# test Loss: 4.2479 Acc: 0.4958
#
# Epoch 59/159
# ----------
# train Loss: 0.0251 Acc: 0.9958
# test Loss: 4.0191 Acc: 0.4542
#
# Epoch 60/159
# ----------
# train Loss: 0.0106 Acc: 0.9983
# test Loss: 4.6510 Acc: 0.4583
#
# Epoch 61/159
# ----------
# train Loss: 0.0089 Acc: 1.0000
# test Loss: 4.4247 Acc: 0.4750
#
# Epoch 62/159
# ----------
# train Loss: 0.0174 Acc: 0.9950
# test Loss: 4.0836 Acc: 0.4875
#
# Epoch 63/159
# ----------
# train Loss: 0.0182 Acc: 0.9975
# test Loss: 4.3137 Acc: 0.4708
#
# Epoch 64/159
# ----------
# train Loss: 0.0157 Acc: 0.9967
# test Loss: 4.3692 Acc: 0.4917
#
# Epoch 65/159
# ----------
# train Loss: 0.0328 Acc: 0.9900
# test Loss: 4.1126 Acc: 0.4917
#
# Epoch 66/159
# ----------
# train Loss: 0.0215 Acc: 0.9950
# test Loss: 4.0040 Acc: 0.4875
#
# Epoch 67/159
# ----------
# train Loss: 0.0253 Acc: 0.9925
# test Loss: 3.4867 Acc: 0.4708
#
# Epoch 68/159
# ----------
# train Loss: 0.0259 Acc: 0.9917
# test Loss: 3.8687 Acc: 0.4750
#
# Epoch 69/159
# ----------
# train Loss: 0.0150 Acc: 0.9975
# test Loss: 3.8728 Acc: 0.4625
#
# Epoch 70/159
# ----------
# train Loss: 0.0072 Acc: 1.0000
# test Loss: 4.1339 Acc: 0.4417
#
# Epoch 71/159
# ----------
# train Loss: 0.0088 Acc: 0.9983
# test Loss: 3.8811 Acc: 0.4958
#
# Epoch 72/159
# ----------
# train Loss: 0.0149 Acc: 0.9975
# test Loss: 4.0825 Acc: 0.4542
#
# Epoch 73/159
# ----------
# train Loss: 0.0249 Acc: 0.9933
# test Loss: 3.8569 Acc: 0.4875
#
# Epoch 74/159
# ----------
# train Loss: 0.0298 Acc: 0.9925
# test Loss: 4.0282 Acc: 0.4458
#
# Epoch 75/159
# ----------
# train Loss: 0.0107 Acc: 0.9975
# test Loss: 4.0565 Acc: 0.4917
#
# Epoch 76/159
# ----------
# train Loss: 0.0037 Acc: 1.0000
# test Loss: 4.1914 Acc: 0.4750
#
# Epoch 77/159
# ----------
# train Loss: 0.0335 Acc: 0.9908
# test Loss: 3.8543 Acc: 0.4750
#
# Epoch 78/159
# ----------
# train Loss: 0.0276 Acc: 0.9908
# test Loss: 4.0848 Acc: 0.4625
#
# Epoch 79/159
# ----------
# train Loss: 0.0134 Acc: 0.9967
# test Loss: 4.1438 Acc: 0.4708
#
# Epoch 80/159
# ----------
# train Loss: 0.0203 Acc: 0.9925
# test Loss: 3.9775 Acc: 0.4625
#
# Epoch 81/159
# ----------
# train Loss: 0.0093 Acc: 0.9992
# test Loss: 4.3821 Acc: 0.4583
#
# Epoch 82/159
# ----------
# train Loss: 0.0161 Acc: 0.9967
# test Loss: 4.0907 Acc: 0.4667
#
# Epoch 83/159
# ----------
# train Loss: 0.0047 Acc: 1.0000
# test Loss: 3.9818 Acc: 0.4708
#
# Epoch 84/159
# ----------
# train Loss: 0.0077 Acc: 0.9983
# test Loss: 3.9454 Acc: 0.4792
#
# Epoch 85/159
# ----------
# train Loss: 0.0201 Acc: 0.9933
# test Loss: 3.8055 Acc: 0.4958
#
# Epoch 86/159
# ----------
# train Loss: 0.0161 Acc: 0.9958
# test Loss: 4.1044 Acc: 0.4958
#
# Epoch 87/159
# ----------
# train Loss: 0.0231 Acc: 0.9925
# test Loss: 4.2450 Acc: 0.4750
#
# Epoch 88/159
# ----------
# train Loss: 0.0087 Acc: 0.9983
# test Loss: 4.3269 Acc: 0.4458
#
# Epoch 89/159
# ----------
# train Loss: 0.0039 Acc: 1.0000
# test Loss: 4.3068 Acc: 0.4625
#
# Epoch 90/159
# ----------
# train Loss: 0.0187 Acc: 0.9958
# test Loss: 4.0185 Acc: 0.4625
#
# Epoch 91/159
# ----------
# train Loss: 0.0121 Acc: 0.9967
# test Loss: 4.1821 Acc: 0.4750
#
# Epoch 92/159
# ----------
# train Loss: 0.0042 Acc: 1.0000
# test Loss: 4.1954 Acc: 0.4917
#
# Epoch 93/159
# ----------
# train Loss: 0.0040 Acc: 1.0000
# test Loss: 4.3313 Acc: 0.4792
#
# Epoch 94/159
# ----------
# train Loss: 0.0058 Acc: 0.9992
# test Loss: 4.2392 Acc: 0.4833
#
# Epoch 95/159
# ----------
# train Loss: 0.0027 Acc: 1.0000
# test Loss: 4.4205 Acc: 0.4958
#
# Epoch 96/159
# ----------
# train Loss: 0.0058 Acc: 0.9975
# test Loss: 4.5043 Acc: 0.4458
#
# Epoch 97/159
# ----------
# train Loss: 0.0445 Acc: 0.9858
# test Loss: 4.7607 Acc: 0.4792
#
# Epoch 98/159
# ----------
# train Loss: 0.0215 Acc: 0.9933
# test Loss: 4.2209 Acc: 0.4667
#
# Epoch 99/159
# ----------
# train Loss: 0.0043 Acc: 0.9992
# test Loss: 4.2026 Acc: 0.4667
#
# Epoch 100/159
# ----------
# train Loss: 0.0034 Acc: 0.9992
# test Loss: 4.0904 Acc: 0.4708
#
# Epoch 101/159
# ----------
# train Loss: 0.0029 Acc: 0.9992
# test Loss: 4.0822 Acc: 0.4625
#
# Epoch 102/159
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 4.1598 Acc: 0.4750
#
# Epoch 103/159
# ----------
# train Loss: 0.0031 Acc: 0.9992
# test Loss: 4.2354 Acc: 0.4708
#
# Epoch 104/159
# ----------
# train Loss: 0.0016 Acc: 1.0000
# test Loss: 4.2311 Acc: 0.4667
#
# Epoch 105/159
# ----------
# train Loss: 0.0021 Acc: 1.0000
# test Loss: 4.2529 Acc: 0.4667
#
# Epoch 106/159
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 4.2745 Acc: 0.4667
#
# Epoch 107/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.2266 Acc: 0.4625
#
# Epoch 108/159
# ----------
# train Loss: 0.0037 Acc: 0.9992
# test Loss: 4.2900 Acc: 0.4667
#
# Epoch 109/159
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 4.3034 Acc: 0.4625
#
# Epoch 110/159
# ----------
# train Loss: 0.0028 Acc: 0.9992
# test Loss: 4.2795 Acc: 0.4750
#
# Epoch 111/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.2496 Acc: 0.4708
#
# Epoch 112/159
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 4.2864 Acc: 0.4750
#
# Epoch 113/159
# ----------
# train Loss: 0.0030 Acc: 0.9992
# test Loss: 4.2841 Acc: 0.4792
#
# Epoch 114/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.4679 Acc: 0.4667
#
# Epoch 115/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.4487 Acc: 0.4708
#
# Epoch 116/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.4578 Acc: 0.4750
#
# Epoch 117/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.4679 Acc: 0.4667
#
# Epoch 118/159
# ----------
# train Loss: 0.0024 Acc: 1.0000
# test Loss: 4.4533 Acc: 0.4542
#
# Epoch 119/159
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 4.4892 Acc: 0.4750
#
# Epoch 120/159
# ----------
# train Loss: 0.0018 Acc: 1.0000
# test Loss: 4.4713 Acc: 0.4583
#
# Epoch 121/159
# ----------
# train Loss: 0.0030 Acc: 1.0000
# test Loss: 4.3775 Acc: 0.4625
#
# Epoch 122/159
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 4.4814 Acc: 0.4417
#
# Epoch 123/159
# ----------
# train Loss: 0.0037 Acc: 0.9992
# test Loss: 4.3538 Acc: 0.4625
#
# Epoch 124/159
# ----------
# train Loss: 0.0015 Acc: 1.0000
# test Loss: 4.3539 Acc: 0.4458
#
# Epoch 125/159
# ----------
# train Loss: 0.0018 Acc: 1.0000
# test Loss: 4.4722 Acc: 0.4625
#
# Epoch 126/159
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 4.4016 Acc: 0.4583
#
# Epoch 127/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.5487 Acc: 0.4583
#
# Epoch 128/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.5084 Acc: 0.4583
#
# Epoch 129/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.4529 Acc: 0.4667
#
# Epoch 130/159
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 4.6097 Acc: 0.4708
#
# Epoch 131/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 4.5980 Acc: 0.4625
#
# Epoch 132/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.7811 Acc: 0.4458
#
# Epoch 133/159
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 4.6653 Acc: 0.4542
#
# Epoch 134/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.5074 Acc: 0.4667
#
# Epoch 135/159
# ----------
# train Loss: 0.0025 Acc: 0.9992
# test Loss: 4.7899 Acc: 0.4708
#
# Epoch 136/159
# ----------
# train Loss: 0.0025 Acc: 0.9992
# test Loss: 4.7108 Acc: 0.4625
#
# Epoch 137/159
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 4.5063 Acc: 0.4667
#
# Epoch 138/159
# ----------
# train Loss: 0.0011 Acc: 1.0000
# test Loss: 4.5874 Acc: 0.4667
#
# Epoch 139/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.7189 Acc: 0.4625
#
# Epoch 140/159
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 4.5250 Acc: 0.4750
#
# Epoch 141/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.7297 Acc: 0.4583
#
# Epoch 142/159
# ----------
# train Loss: 0.0038 Acc: 0.9992
# test Loss: 4.6657 Acc: 0.4583
#
# Epoch 143/159
# ----------
# train Loss: 0.0015 Acc: 1.0000
# test Loss: 4.5116 Acc: 0.4625
#
# Epoch 144/159
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 4.4717 Acc: 0.4708
#
# Epoch 145/159
# ----------
# train Loss: 0.0029 Acc: 0.9992
# test Loss: 4.5433 Acc: 0.4625
#
# Epoch 146/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.4551 Acc: 0.4583
#
# Epoch 147/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 4.5047 Acc: 0.4583
#
# Epoch 148/159
# ----------
# train Loss: 0.0015 Acc: 1.0000
# test Loss: 4.5969 Acc: 0.4542
#
# Epoch 149/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.4350 Acc: 0.4583
#
# Epoch 150/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.5507 Acc: 0.4542
#
# Epoch 151/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.5801 Acc: 0.4625
#
# Epoch 152/159
# ----------
# train Loss: 0.0021 Acc: 1.0000
# test Loss: 4.7181 Acc: 0.4583
#
# Epoch 153/159
# ----------
# train Loss: 0.0040 Acc: 0.9992
# test Loss: 4.4911 Acc: 0.4667
#
# Epoch 154/159
# ----------
# train Loss: 0.0011 Acc: 1.0000
# test Loss: 4.6296 Acc: 0.4750
#
# Epoch 155/159
# ----------
# train Loss: 0.0014 Acc: 1.0000
# test Loss: 4.7119 Acc: 0.4583
#
# Epoch 156/159
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 4.7833 Acc: 0.4583
#
# Epoch 157/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 4.6295 Acc: 0.4667
#
# Epoch 158/159
# ----------
# train Loss: 0.0018 Acc: 1.0000
# test Loss: 4.6248 Acc: 0.4583
#
# Epoch 159/159
# ----------
# train Loss: 0.0024 Acc: 0.9992
# test Loss: 4.5800 Acc: 0.4667
#
# Training complete in 12m 16s
# Best val Acc: 0.512500

# %%
epochsLst = range(0,epochs)
plt.plot(epochsLst, train_loss, 'g', label='Training loss')
plt.plot(epochsLst, test_loss, 'b', label='Testing loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('loss_alex.png')
plt.show()

# %%
epochsLst = range(0,epochs)
plt.plot(epochsLst, train_acc, 'g', label='Training acc.')
plt.plot(epochsLst, test_acc, 'b', label='validation acc.')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('accuracy_alex.png')
plt.show()

# %% [markdown]
# # Train ResNet18 WITH JET encoding

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3,1,1))
    ]),
    'test': transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3,1,1))
    ]),
}

data_dir = '../input/pytorchdata/data/librosa'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=8,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model_ft = torchvision.models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

print(model_ft)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0001,weight_decay=0.001)

# Decay LR by a factor of 0.1 every 30 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=100, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=8, bias=True)
# )

# %%
model, train_acc, train_loss, test_acc, test_loss = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=epochs)
torch.save(model.state_dict(), 'emotionRecognition_restnet.pt')
# Out:
# Epoch 0/159
# ----------
# train Loss: 1.5108 Acc: 0.4225
# test Loss: 1.5347 Acc: 0.4792
#
# Epoch 1/159
# ----------
# train Loss: 0.6549 Acc: 0.7900
# test Loss: 1.5709 Acc: 0.5000
#
# Epoch 2/159
# ----------
# train Loss: 0.2533 Acc: 0.9342
# test Loss: 1.7872 Acc: 0.4417
#
# Epoch 3/159
# ----------
# train Loss: 0.1230 Acc: 0.9808
# test Loss: 1.6930 Acc: 0.4875
#
# Epoch 4/159
# ----------
# train Loss: 0.0644 Acc: 0.9950
# test Loss: 1.8947 Acc: 0.4708
#
# Epoch 5/159
# ----------
# train Loss: 0.0571 Acc: 0.9950
# test Loss: 1.7533 Acc: 0.4792
#
# Epoch 6/159
# ----------
# train Loss: 0.0811 Acc: 0.9817
# test Loss: 1.8588 Acc: 0.4625
#
# Epoch 7/159
# ----------
# train Loss: 0.1055 Acc: 0.9750
# test Loss: 1.8975 Acc: 0.5042
#
# Epoch 8/159
# ----------
# train Loss: 0.1007 Acc: 0.9708
# test Loss: 2.0364 Acc: 0.4875
#
# Epoch 9/159
# ----------
# train Loss: 0.1278 Acc: 0.9617
# test Loss: 2.0094 Acc: 0.4500
#
# Epoch 10/159
# ----------
# train Loss: 0.0879 Acc: 0.9817
# test Loss: 1.6902 Acc: 0.5000
#
# Epoch 11/159
# ----------
# train Loss: 0.0918 Acc: 0.9733
# test Loss: 2.2455 Acc: 0.4333
#
# Epoch 12/159
# ----------
# train Loss: 0.0958 Acc: 0.9700
# test Loss: 1.7647 Acc: 0.5167
#
# Epoch 13/159
# ----------
# train Loss: 0.1067 Acc: 0.9717
# test Loss: 1.6545 Acc: 0.5167
#
# Epoch 14/159
# ----------
# train Loss: 0.0749 Acc: 0.9783
# test Loss: 2.2313 Acc: 0.4542
#
# Epoch 15/159
# ----------
# train Loss: 0.0681 Acc: 0.9825
# test Loss: 2.1964 Acc: 0.4875
#
# Epoch 16/159
# ----------
# train Loss: 0.0475 Acc: 0.9900
# test Loss: 2.0565 Acc: 0.4958
#
# Epoch 17/159
# ----------
# train Loss: 0.0378 Acc: 0.9933
# test Loss: 2.1023 Acc: 0.4792
#
# Epoch 18/159
# ----------
# train Loss: 0.0253 Acc: 0.9975
# test Loss: 2.3058 Acc: 0.4792
#
# Epoch 19/159
# ----------
# train Loss: 0.0744 Acc: 0.9833
# test Loss: 2.2787 Acc: 0.4708
#
# Epoch 20/159
# ----------
# train Loss: 0.0566 Acc: 0.9833
# test Loss: 2.5083 Acc: 0.4667
#
# Epoch 21/159
# ----------
# train Loss: 0.0431 Acc: 0.9925
# test Loss: 2.2209 Acc: 0.4375
#
# Epoch 22/159
# ----------
# train Loss: 0.0442 Acc: 0.9883
# test Loss: 2.1652 Acc: 0.5000
#
# Epoch 23/159
# ----------
# train Loss: 0.0353 Acc: 0.9925
# test Loss: 1.9359 Acc: 0.5208
#
# Epoch 24/159
# ----------
# train Loss: 0.0234 Acc: 0.9967
# test Loss: 2.0019 Acc: 0.4750
#
# Epoch 25/159
# ----------
# train Loss: 0.0399 Acc: 0.9883
# test Loss: 2.4438 Acc: 0.4292
#
# Epoch 26/159
# ----------
# train Loss: 0.0794 Acc: 0.9783
# test Loss: 2.2693 Acc: 0.4667
#
# Epoch 27/159
# ----------
# train Loss: 0.0949 Acc: 0.9692
# test Loss: 2.4365 Acc: 0.4250
#
# Epoch 28/159
# ----------
# train Loss: 0.0826 Acc: 0.9725
# test Loss: 2.2214 Acc: 0.4667
#
# Epoch 29/159
# ----------
# train Loss: 0.0578 Acc: 0.9825
# test Loss: 2.2035 Acc: 0.5083
#
# Epoch 30/159
# ----------
# train Loss: 0.0430 Acc: 0.9883
# test Loss: 2.4042 Acc: 0.5000
#
# Epoch 31/159
# ----------
# train Loss: 0.0375 Acc: 0.9892
# test Loss: 2.6936 Acc: 0.4292
#
# Epoch 32/159
# ----------
# train Loss: 0.0465 Acc: 0.9867
# test Loss: 1.9066 Acc: 0.5083
#
# Epoch 33/159
# ----------
# train Loss: 0.0363 Acc: 0.9892
# test Loss: 2.1561 Acc: 0.5458
#
# Epoch 34/159
# ----------
# train Loss: 0.0170 Acc: 1.0000
# test Loss: 2.0494 Acc: 0.5417
#
# Epoch 35/159
# ----------
# train Loss: 0.0286 Acc: 0.9917
# test Loss: 2.0632 Acc: 0.5042
#
# Epoch 36/159
# ----------
# train Loss: 0.0138 Acc: 0.9992
# test Loss: 2.2484 Acc: 0.5042
#
# Epoch 37/159
# ----------
# train Loss: 0.0371 Acc: 0.9925
# test Loss: 1.9935 Acc: 0.5417
#
# Epoch 38/159
# ----------
# train Loss: 0.0589 Acc: 0.9800
# test Loss: 2.0704 Acc: 0.5375
#
# Epoch 39/159
# ----------
# train Loss: 0.0582 Acc: 0.9858
# test Loss: 1.8714 Acc: 0.5208
#
# Epoch 40/159
# ----------
# train Loss: 0.0753 Acc: 0.9758
# test Loss: 1.9369 Acc: 0.4875
#
# Epoch 41/159
# ----------
# train Loss: 0.0389 Acc: 0.9917
# test Loss: 1.8668 Acc: 0.5250
#
# Epoch 42/159
# ----------
# train Loss: 0.0505 Acc: 0.9850
# test Loss: 2.1466 Acc: 0.4917
#
# Epoch 43/159
# ----------
# train Loss: 0.0377 Acc: 0.9908
# test Loss: 1.9243 Acc: 0.5542
#
# Epoch 44/159
# ----------
# train Loss: 0.0324 Acc: 0.9917
# test Loss: 2.2247 Acc: 0.5333
#
# Epoch 45/159
# ----------
# train Loss: 0.0307 Acc: 0.9892
# test Loss: 2.2794 Acc: 0.5250
#
# Epoch 46/159
# ----------
# train Loss: 0.0300 Acc: 0.9917
# test Loss: 2.2994 Acc: 0.4708
#
# Epoch 47/159
# ----------
# train Loss: 0.0349 Acc: 0.9900
# test Loss: 2.4661 Acc: 0.4583
#
# Epoch 48/159
# ----------
# train Loss: 0.0657 Acc: 0.9783
# test Loss: 2.3879 Acc: 0.4708
#
# Epoch 49/159
# ----------
# train Loss: 0.0365 Acc: 0.9925
# test Loss: 2.3392 Acc: 0.4667
#
# Epoch 50/159
# ----------
# train Loss: 0.0326 Acc: 0.9892
# test Loss: 2.1368 Acc: 0.5167
#
# Epoch 51/159
# ----------
# train Loss: 0.0330 Acc: 0.9925
# test Loss: 2.2211 Acc: 0.5000
#
# Epoch 52/159
# ----------
# train Loss: 0.0318 Acc: 0.9908
# test Loss: 2.3254 Acc: 0.4125
#
# Epoch 53/159
# ----------
# train Loss: 0.0786 Acc: 0.9767
# test Loss: 2.0851 Acc: 0.4750
#
# Epoch 54/159
# ----------
# train Loss: 0.0384 Acc: 0.9925
# test Loss: 2.2007 Acc: 0.4833
#
# Epoch 55/159
# ----------
# train Loss: 0.0447 Acc: 0.9883
# test Loss: 1.7929 Acc: 0.5125
#
# Epoch 56/159
# ----------
# train Loss: 0.0321 Acc: 0.9942
# test Loss: 1.7686 Acc: 0.5583
#
# Epoch 57/159
# ----------
# train Loss: 0.0522 Acc: 0.9808
# test Loss: 2.2658 Acc: 0.4958
#
# Epoch 58/159
# ----------
# train Loss: 0.0299 Acc: 0.9942
# test Loss: 1.9437 Acc: 0.5250
#
# Epoch 59/159
# ----------
# train Loss: 0.0215 Acc: 0.9967
# test Loss: 1.9539 Acc: 0.4792
#
# Epoch 60/159
# ----------
# train Loss: 0.0199 Acc: 0.9950
# test Loss: 2.0235 Acc: 0.5042
#
# Epoch 61/159
# ----------
# train Loss: 0.0368 Acc: 0.9892
# test Loss: 2.3835 Acc: 0.4875
#
# Epoch 62/159
# ----------
# train Loss: 0.0374 Acc: 0.9875
# test Loss: 1.8560 Acc: 0.5250
#
# Epoch 63/159
# ----------
# train Loss: 0.0295 Acc: 0.9950
# test Loss: 2.1746 Acc: 0.5000
#
# Epoch 64/159
# ----------
# train Loss: 0.0588 Acc: 0.9858
# test Loss: 1.8970 Acc: 0.5208
#
# Epoch 65/159
# ----------
# train Loss: 0.0407 Acc: 0.9908
# test Loss: 1.8057 Acc: 0.5208
#
# Epoch 66/159
# ----------
# train Loss: 0.0225 Acc: 0.9967
# test Loss: 2.0750 Acc: 0.5042
#
# Epoch 67/159
# ----------
# train Loss: 0.0232 Acc: 0.9958
# test Loss: 2.3460 Acc: 0.4792
#
# Epoch 68/159
# ----------
# train Loss: 0.0171 Acc: 0.9983
# test Loss: 2.0428 Acc: 0.5292
#
# Epoch 69/159
# ----------
# train Loss: 0.0082 Acc: 1.0000
# test Loss: 2.2012 Acc: 0.5208
#
# Epoch 70/159
# ----------
# train Loss: 0.0112 Acc: 0.9975
# test Loss: 2.1554 Acc: 0.5083
#
# Epoch 71/159
# ----------
# train Loss: 0.0052 Acc: 1.0000
# test Loss: 2.0060 Acc: 0.5000
#
# Epoch 72/159
# ----------
# train Loss: 0.0036 Acc: 1.0000
# test Loss: 1.9765 Acc: 0.5167
#
# Epoch 73/159
# ----------
# train Loss: 0.0061 Acc: 0.9992
# test Loss: 2.1318 Acc: 0.5292
#
# Epoch 74/159
# ----------
# train Loss: 0.0382 Acc: 0.9892
# test Loss: 2.3837 Acc: 0.4625
#
# Epoch 75/159
# ----------
# train Loss: 0.1507 Acc: 0.9550
# test Loss: 2.6913 Acc: 0.4208
#
# Epoch 76/159
# ----------
# train Loss: 0.1355 Acc: 0.9508
# test Loss: 2.0833 Acc: 0.4833
#
# Epoch 77/159
# ----------
# train Loss: 0.0439 Acc: 0.9917
# test Loss: 1.9201 Acc: 0.5250
#
# Epoch 78/159
# ----------
# train Loss: 0.0325 Acc: 0.9942
# test Loss: 2.0065 Acc: 0.5042
#
# Epoch 79/159
# ----------
# train Loss: 0.0251 Acc: 0.9933
# test Loss: 1.9544 Acc: 0.5333
#
# Epoch 80/159
# ----------
# train Loss: 0.0247 Acc: 0.9942
# test Loss: 2.2883 Acc: 0.4500
#
# Epoch 81/159
# ----------
# train Loss: 0.0100 Acc: 0.9992
# test Loss: 1.9243 Acc: 0.5458
#
# Epoch 82/159
# ----------
# train Loss: 0.0136 Acc: 0.9983
# test Loss: 1.9840 Acc: 0.5000
#
# Epoch 83/159
# ----------
# train Loss: 0.0115 Acc: 0.9983
# test Loss: 2.0819 Acc: 0.5167
#
# Epoch 84/159
# ----------
# train Loss: 0.0064 Acc: 0.9992
# test Loss: 1.9054 Acc: 0.4958
#
# Epoch 85/159
# ----------
# train Loss: 0.0115 Acc: 0.9983
# test Loss: 2.0151 Acc: 0.5083
#
# Epoch 86/159
# ----------
# train Loss: 0.0142 Acc: 0.9967
# test Loss: 2.0809 Acc: 0.4833
#
# Epoch 87/159
# ----------
# train Loss: 0.0170 Acc: 0.9983
# test Loss: 2.0722 Acc: 0.5167
#
# Epoch 88/159
# ----------
# train Loss: 0.0229 Acc: 0.9950
# test Loss: 2.0395 Acc: 0.4792
#
# Epoch 89/159
# ----------
# train Loss: 0.0490 Acc: 0.9892
# test Loss: 2.3513 Acc: 0.4833
#
# Epoch 90/159
# ----------
# train Loss: 0.0569 Acc: 0.9858
# test Loss: 2.0566 Acc: 0.4917
#
# Epoch 91/159
# ----------
# train Loss: 0.0880 Acc: 0.9667
# test Loss: 2.1680 Acc: 0.4875
#
# Epoch 92/159
# ----------
# train Loss: 0.0558 Acc: 0.9867
# test Loss: 2.0029 Acc: 0.5167
#
# Epoch 93/159
# ----------
# train Loss: 0.0423 Acc: 0.9925
# test Loss: 1.9948 Acc: 0.5375
#
# Epoch 94/159
# ----------
# train Loss: 0.0292 Acc: 0.9925
# test Loss: 1.9442 Acc: 0.4750
#
# Epoch 95/159
# ----------
# train Loss: 0.0232 Acc: 0.9933
# test Loss: 1.6762 Acc: 0.5500
#
# Epoch 96/159
# ----------
# train Loss: 0.0144 Acc: 0.9967
# test Loss: 2.0476 Acc: 0.5167
#
# Epoch 97/159
# ----------
# train Loss: 0.0456 Acc: 0.9892
# test Loss: 2.0559 Acc: 0.4583
#
# Epoch 98/159
# ----------
# train Loss: 0.0325 Acc: 0.9925
# test Loss: 1.9886 Acc: 0.4917
#
# Epoch 99/159
# ----------
# train Loss: 0.0113 Acc: 1.0000
# test Loss: 1.9848 Acc: 0.4958
#
# Epoch 100/159
# ----------
# train Loss: 0.0078 Acc: 0.9992
# test Loss: 1.8371 Acc: 0.5167
#
# Epoch 101/159
# ----------
# train Loss: 0.0062 Acc: 1.0000
# test Loss: 1.9615 Acc: 0.4917
#
# Epoch 102/159
# ----------
# train Loss: 0.0055 Acc: 1.0000
# test Loss: 1.8808 Acc: 0.5083
#
# Epoch 103/159
# ----------
# train Loss: 0.0051 Acc: 1.0000
# test Loss: 1.9379 Acc: 0.5042
#
# Epoch 104/159
# ----------
# train Loss: 0.0045 Acc: 1.0000
# test Loss: 1.9046 Acc: 0.5000
#
# Epoch 105/159
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.9174 Acc: 0.5167
#
# Epoch 106/159
# ----------
# train Loss: 0.0040 Acc: 1.0000
# test Loss: 1.9013 Acc: 0.5042
#
# Epoch 107/159
# ----------
# train Loss: 0.0032 Acc: 1.0000
# test Loss: 1.9335 Acc: 0.5000
#
# Epoch 108/159
# ----------
# train Loss: 0.0031 Acc: 1.0000
# test Loss: 1.8618 Acc: 0.5167
#
# Epoch 109/159
# ----------
# train Loss: 0.0033 Acc: 1.0000
# test Loss: 1.9754 Acc: 0.4917
#
# Epoch 110/159
# ----------
# train Loss: 0.0035 Acc: 1.0000
# test Loss: 1.9612 Acc: 0.5125
#
# Epoch 111/159
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 2.1204 Acc: 0.5125
#
# Epoch 112/159
# ----------
# train Loss: 0.0029 Acc: 1.0000
# test Loss: 1.8920 Acc: 0.5167
#
# Epoch 113/159
# ----------
# train Loss: 0.0039 Acc: 1.0000
# test Loss: 1.9008 Acc: 0.5292
#
# Epoch 114/159
# ----------
# train Loss: 0.0030 Acc: 1.0000
# test Loss: 1.8933 Acc: 0.5208
#
# Epoch 115/159
# ----------
# train Loss: 0.0031 Acc: 1.0000
# test Loss: 1.7688 Acc: 0.5292
#
# Epoch 116/159
# ----------
# train Loss: 0.0054 Acc: 0.9983
# test Loss: 2.0628 Acc: 0.5000
#
# Epoch 117/159
# ----------
# train Loss: 0.0033 Acc: 1.0000
# test Loss: 1.8459 Acc: 0.5292
#
# Epoch 118/159
# ----------
# train Loss: 0.0026 Acc: 1.0000
# test Loss: 1.9136 Acc: 0.5000
#
# Epoch 119/159
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.9087 Acc: 0.5042
#
# Epoch 120/159
# ----------
# train Loss: 0.0028 Acc: 1.0000
# test Loss: 1.9183 Acc: 0.5000
#
# Epoch 121/159
# ----------
# train Loss: 0.0027 Acc: 1.0000
# test Loss: 1.8914 Acc: 0.5083
#
# Epoch 122/159
# ----------
# train Loss: 0.0018 Acc: 1.0000
# test Loss: 1.8253 Acc: 0.5250
#
# Epoch 123/159
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 1.7982 Acc: 0.5042
#
# Epoch 124/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 1.8205 Acc: 0.5208
#
# Epoch 125/159
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 2.0093 Acc: 0.5042
#
# Epoch 126/159
# ----------
# train Loss: 0.0016 Acc: 1.0000
# test Loss: 1.8027 Acc: 0.5333
#
# Epoch 127/159
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 1.8965 Acc: 0.5208
#
# Epoch 128/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 1.8262 Acc: 0.5083
#
# Epoch 129/159
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.9220 Acc: 0.5125
#
# Epoch 130/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.8908 Acc: 0.5292
#
# Epoch 131/159
# ----------
# train Loss: 0.0022 Acc: 1.0000
# test Loss: 1.7938 Acc: 0.5167
#
# Epoch 132/159
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.8978 Acc: 0.5042
#
# Epoch 133/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 2.1756 Acc: 0.4833
#
# Epoch 134/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.7905 Acc: 0.5333
#
# Epoch 135/159
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.8696 Acc: 0.5333
#
# Epoch 136/159
# ----------
# train Loss: 0.0072 Acc: 0.9983
# test Loss: 1.9833 Acc: 0.4917
#
# Epoch 137/159
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.8186 Acc: 0.5083
#
# Epoch 138/159
# ----------
# train Loss: 0.0016 Acc: 1.0000
# test Loss: 1.8681 Acc: 0.5125
#
# Epoch 139/159
# ----------
# train Loss: 0.0015 Acc: 1.0000
# test Loss: 1.8544 Acc: 0.4917
#
# Epoch 140/159
# ----------
# train Loss: 0.0026 Acc: 1.0000
# test Loss: 1.8374 Acc: 0.5042
#
# Epoch 141/159
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.9131 Acc: 0.4833
#
# Epoch 142/159
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.7780 Acc: 0.5125
#
# Epoch 143/159
# ----------
# train Loss: 0.0023 Acc: 1.0000
# test Loss: 1.7646 Acc: 0.5167
#
# Epoch 144/159
# ----------
# train Loss: 0.0015 Acc: 1.0000
# test Loss: 1.8493 Acc: 0.5042
#
# Epoch 145/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.7974 Acc: 0.5208
#
# Epoch 146/159
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.8192 Acc: 0.5208
#
# Epoch 147/159
# ----------
# train Loss: 0.0010 Acc: 1.0000
# test Loss: 1.7866 Acc: 0.5375
#
# Epoch 148/159
# ----------
# train Loss: 0.0025 Acc: 1.0000
# test Loss: 1.7494 Acc: 0.5333
#
# Epoch 149/159
# ----------
# train Loss: 0.0016 Acc: 1.0000
# test Loss: 1.6798 Acc: 0.5333
#
# Epoch 150/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.7852 Acc: 0.5375
#
# Epoch 151/159
# ----------
# train Loss: 0.0024 Acc: 0.9992
# test Loss: 1.9934 Acc: 0.4833
#
# Epoch 152/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.8903 Acc: 0.4875
#
# Epoch 153/159
# ----------
# train Loss: 0.0009 Acc: 1.0000
# test Loss: 1.8661 Acc: 0.4958
#
# Epoch 154/159
# ----------
# train Loss: 0.0019 Acc: 1.0000
# test Loss: 1.8564 Acc: 0.5000
#
# Epoch 155/159
# ----------
# train Loss: 0.0013 Acc: 1.0000
# test Loss: 1.7500 Acc: 0.5292
#
# Epoch 156/159
# ----------
# train Loss: 0.0017 Acc: 1.0000
# test Loss: 1.8328 Acc: 0.5208
#
# Epoch 157/159
# ----------
# train Loss: 0.0012 Acc: 1.0000
# test Loss: 1.7566 Acc: 0.5167
#
# Epoch 158/159
# ----------
# train Loss: 0.0009 Acc: 1.0000
# test Loss: 1.8070 Acc: 0.5125
#
# Epoch 159/159
# ----------
# train Loss: 0.0020 Acc: 1.0000
# test Loss: 1.8526 Acc: 0.5125
#
# Training complete in 13m 36s
# Best val Acc: 0.558333

# %%
epochsLst = range(0,epochs)
plt.plot(epochsLst, train_loss, 'g', label='Training loss')
plt.plot(epochsLst, test_loss, 'b', label='Testing loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('loss_resnet.png')
plt.show()

# %%
epochsLst = range(0,epochs)
plt.plot(epochsLst, train_acc, 'g', label='Training acc.')
plt.plot(epochsLst, test_acc, 'b', label='validation acc.')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('accuracy_resnet.png')
plt.show()
